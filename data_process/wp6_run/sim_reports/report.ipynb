# %%
# %matplotlib inline
import os
import sys
source_folder = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.realpath('__file__')))))
sys.path.insert(0, source_folder)
from data_process.wp6_run.sim_reports.utils import *
from delphin_6_automation.database_interactions import mongo_setup
from delphin_6_automation.database_interactions.auth import auth_dict
plt.rcParams["figure.figsize"] = (10,5)
server = mongo_setup.global_init(auth_dict)
# Out:
# 2019-07-05 16:46:45,346 - INFO - mongo_setup.py - global_init - Connected to server

# %% [markdown]
# # Simulated Projects

# %%
print(get_simulated_projects_count())
# Out:
# 34928

# %% [markdown]
# # Simulation Time Stats

# %%
times = get_simulation_time()
for key in times.keys():
    if key == 'gt_250':
        print(f'\tLonger simulation time than 250min: {times[key]}')
    else:    
        print(f'\t{key.upper()}: {times[key]:.2f}min')
# Out:
# 	MIN: 0.53min
# 	Q25: 1.09min
# 	MEAN: 83.06min
# 	MEDIAN: 11.70min
# 	Q75: 250.00min
# 	Q95: 251.17min
# 	MAX: 290.65min
# 	Longer simulation time than 250min: 9439

# %%
get_simulation_time_plot()

# %% [markdown]
# # Actual Average Simulation Time
# Time since the first simulation finished devided by number of simulated projects

# %%
print(f'{get_actual_average_simulation_time():.2f} min/project')
# Out:
# 1.60 min/project

# %% [markdown]
# # Convergence Plots

# %%
get_convergence_mould()

# %%
get_convergence_heatloss()

# %% [markdown]
# # CDF Plots

# %%
get_mould_cdf()

# %%
get_heatloss_cdf()

# %%
mongo_setup.global_end_ssh(server)
